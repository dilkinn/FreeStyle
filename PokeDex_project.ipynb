# %%
import numpy as np
import pandas as pd

#Pokemon_Cards - Gotta Catch Them All

df = pd.read_csv ('data/pokemon.csv')

# %%
df.head()
# Out:
#    #                                      abilities  against_bug  \
# 0  0                 ['Snow Warning', 'Soundproof']         2.00
# 1  1  ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 2  2        ['Pressure', 'Super Luck', 'Justified']         2.00
# 3  3       ['Hydration', 'Sticky Hold', 'Unburden']         1.00
# 4  4                              ['Stance Change']         0.25
#
#    against_dark  against_dragon  against_electric  against_fairy  \
# 0           1.0             1.0               0.5            1.0
# 1           2.0             1.0               1.0            1.0
# 2           0.5             1.0               1.0            2.0
# 3           1.0             1.0               1.0            1.0
# 4           2.0             0.5               1.0            0.5
#
#    against_fight  against_fire  against_flying  ...  percentage_male  \
# 0            2.0           4.0             2.0  ...             50.0
# ...

# %%
#df['name'].head()
df.rename(columns={'#': 'id#'}, inplace=True)
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#    id#                                      abilities  against_bug  \
# 0    0                 ['Snow Warning', 'Soundproof']         2.00
# 1    1  ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 2    2        ['Pressure', 'Super Luck', 'Justified']         2.00
# 3    3       ['Hydration', 'Sticky Hold', 'Unburden']         1.00
# 4    4                              ['Stance Change']         0.25
#
#    against_dark  against_dragon  against_electric  against_fairy  \
# 0           1.0             1.0               0.5            1.0
# 1           2.0             1.0               1.0            1.0
# 2           0.5             1.0               1.0            2.0
# 3           1.0             1.0               1.0            1.0
# 4           2.0             0.5               1.0            0.5
#
#    against_fight  against_fire  against_flying  ...  percentage_male  \
# 0            2.0           4.0             2.0  ...             50.0
# ...

# %%
word = []
list_of_abilities = list(df['abilities'])
for i in list_of_abilities:
    word.append(i)
print(word[0][:])
# Out:
# ['Snow Warning', 'Soundproof']

# %%
class PokemonCards():
    '''Data involving Pokemon'''
    #Could Not Find Color of Each Pokemon - Probably manipulate data later(assign color to each pokemon).
    
    #Store info for each card
    def __init__(self,card):
        self.abilities = card['abilities']
        self.name = card['name']
        self.health_points = card['hp']
        self.weight_of_pokemon = card['weight_kg']
        self.first_type = card['type1']
        self.speed = card['speed']
        self.capture_rate = card['capture_rate']
        self.class_group = card['classification']

# %%
e = df.iloc[0:40]
e
# Out:
#     id#                                          abilities  against_bug  \
# 0     0                     ['Snow Warning', 'Soundproof']         2.00
# 1     1      ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 2     2            ['Pressure', 'Super Luck', 'Justified']         2.00
# 3     3           ['Hydration', 'Sticky Hold', 'Unburden']         1.00
# 4     4                                  ['Stance Change']         0.25
# 5     5               ['Rock Head', 'Pressure', 'Unnerve']         0.50
# 6     6             ['Sturdy', 'Rock Head', 'Heavy Metal']         0.50
# 7     7               ['Run Away', 'Pickup', 'Skill Link']         1.00
# 8     8      ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 9     9             ['Healer', 'Hydration', 'Regenerator']         1.00
# 10   10                     ['Natural Cure', 'Cloud Nine']         0.50
# 11   11                    ['Refrigerate', 'Snow Warning']         1.00
# ...

# %%
print(type(e.name))
# Out:
# <class 'pandas.core.series.Series'>
